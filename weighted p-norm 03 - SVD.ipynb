# %% [markdown]
# # The weighted generalized mean model of concurrency with Raphson's method - invertability of the Hessian
# Is the Hessian invertable? How badly conditioned is it?

# %%
# %matplotlib inline

# %%
from collections import defaultdict
import theano
import matplotlib.pyplot as plt
import matplotlib.cm as cm
from theano import pp
from theano import tensor as T
from theano import function
from theano.ifelse import ifelse
import numpy as np

# %% [markdown]
# # An exhaustive study of the errors based on synthetic data
# ### The weighted generalized mean model
#
# $$
# M(\mathbf{x}, \mathbf{w}, p) =
#  \left\{
#   \begin{array}{cl}
# 	\left(\sum_{i=1}^n w_i x_i^p \right)^{\frac{1}{p}}
#  	& \texttt{if } p \neq 0 \\
#  	\prod_{i=1}^n x_i^{w_i}
#  	& \texttt{if } p=0 \\
#   \end{array}
#  \right.
# $$
#
# $$
# RT(\mathbf{x}, \mathbf{w}, p, \mu,\sigma) = M(\mathbf{x}, \mathbf{w}, p)  + \exp({\mathcal{N}(\mu,\,\sigma^{2})\,})
# $$
#
# $$
# \mathbf{x} = \exp({\mathcal{N}(...,\,...)\,})
# $$

# %% [markdown]
# ## Synthetize data with the weighted generalized mean

# %%
class WeightedPNormSample(object):
    
    def __init__(self, locX, scaleX, w, p, mu, sigma, training_set_size, validation_set_size, test_set_size):
        """ @param locX: location parameters of log-norm distribution of child transactions
            @param scaleX: scale parameters of log-norm distribution of child transactions
            @param w: weigth parameters of child transactions
            @param p: 
            @param mu: locataion param of log-norm additive noise
            @param sigma: scale param of log-norm additive noise
        """
        self.locX, self.scaleX, self.real_w, self.real_p, self.real_mu, self.real_sigma, = \
             locX,      scaleX,           w,           p,           mu,          sigma, 
        self.training_set_size, self.validation_set_size, self.test_set_size = \
             training_set_size,      validation_set_size,      test_set_size
            
        self.numChildren = len(locX)    
        assert self.locX.shape == (self.numChildren,)
        assert self.scaleX.shape == (self.numChildren,)
        assert self.real_w.shape == (self.numChildren,)
        if verbose:
            print "Generating {} training, {} validation and {} test samples using the following parameters:" \
                .format(training_set_size, validation_set_size, test_set_size)
            print "locX = {}        scaleX = {}".format(self.locX, self.scaleX)
            print "w = {},        p = {},        mu = {},        sigma = {}"\
                    .format(self.real_w, self.real_p, self.real_mu, self.real_sigma)
        self.train_X_samples     , self.train_RT_samples      = self._sample(training_set_size  ,) 
        self.validation_X_samples, self.validation_RT_samples = self._sample(validation_set_size,)  
        self.test_X_samples      , self.test_RT_samples       = self._sample(test_set_size      ,)

    def _sample(self, N, ):
        """ @param N: number of samples to generate
        """
        X_samples = np.stack((np.exp(np.random.normal(self.locX[child], 
                                                           self.scaleX[child], N)) 
                                   for child in range(self.numChildren)), axis=1)
        M = np.power(np.dot(np.power(X_samples, self.real_p), self.real_w), 1.0/self.real_p)
        RT_samples = M + np.exp(np.random.normal(self.real_mu, self.real_sigma, len(M)))
        return X_samples, RT_samples

# %% [markdown]
# ## Raphson's method to fit the model

# %%
class WeightedPNormNR(object):
    """ Newton-raphson method to fit a weighted p-norm model. 
    
        See https://en.wikipedia.org/wiki/Newton%27s_method_in_optimization
    """
    num_children = 3
    
    l = T.dscalar('lambda')  # regularization parameter
    # the model parameters
    wpm = theano.shared(np.zeros(num_children + 2), 'wpm')    #T.concatenate([w, T.stack([p, m])])

    # model parameter: weights of child transactions
    w = wpm[:num_children]
    # model parameter: power of child resp times
    p = wpm[num_children]
    # # model param: 
    # mu = theano.shared(0.0, 'mu')        # mean of normal distrib
    # sigma = theano.shared(1.0, 'sigma')  # stddev of normal
    # for now we use 
    m = wpm[num_children+1]

    # every row (selected by 0th coord) is an observation, 
    # fields in a row (1st coord) are child trx resp time in the observation
    X = T.dmatrix('X')  

    # parent resp time, each observation on a separate row
    y = T.dvector('y')

    step_size = T.dscalar('step_size')

    # The expected response time from the model we use:
    XP = T.pow(X, p)
    XPw = T.dot(XP, w)
    #sXPw = T.sum(XPw, axis=0)
    RT = T.pow(XPw, 1/p) + T.exp(m)

    # residual:
    epsilon = y - RT
    
    # penalty if sum of w is not one ...
    #regularization_1 = T.pow((w - 1.0/num_children), 2).sum()*1e-1
    # ... and if negative
    regularization_2 = T.exp((-w-.05)*100).sum() + T.exp((w-1.1)*100).sum() + T.exp(-p*100) + T.exp((p-10)*100)
    
    # Mean squared error
    MSE = 0.5 * T.pow(epsilon, 2).mean() 
    
    # the cost function
    E = MSE + regularization_2

    # the gradient:
    gradE = T.grad(E, wpm)
    
    # the hessian:
    H = T.hessian(E, wpm)
    
    # Singular value decomposition: H = U.D.V    where D.shape is linear
    U, D, V = theano.tensor.nlinalg.svd(H + T.diag(T.ones(num_children + 2) * l))  # contrary to theano docu stating U, V, D
    
    # The inverse is computed by V.D^{-1}.U
    U_gradE = T.dot(U, gradE)
    Dinv_U_gradE = U_gradE / D   # element-wise
    V_Dinv_U_gradE = T.dot(V, Dinv_U_gradE)  
    
    new_wpm = wpm - step_size * V_Dinv_U_gradE
    
    training_result_variables = ('wpm', 'XPw', 'RT', 'epsilon', 'regularization_2', 'MSE', 'E',  
                                 'gradE', 'U', 'V', 'D', 'new_wpm', )
    train = staticmethod(theano.function(
              inputs=[X, y, step_size, l],
              outputs=[wpm, XPw, RT, epsilon, regularization_2, MSE, E, gradE, U, V, D, new_wpm],
              updates=((wpm, new_wpm), )
    ))
    prediction_result_variables = 'RT', 'epsilon', 'MSE'
    predict = staticmethod(theano.function(inputs=[X, y], outputs=[RT, epsilon, MSE]))

    def __init__(self, w_init, p_init, m_init, step_size_, l_, training_steps, data, MSE_limit):
        self.w_init, self.p_init, self.m_init, self.step_size_, self.l_, self.training_steps,  self.MSE_limit = \
             w_init,      p_init,      m_init,      step_size_,      l_,      training_steps,       MSE_limit

        if verbose:
            print ("Training the model using the following parameters:"
                   "\nstep_size = {},\tlambda = {},\ttraining_steps = {}" \
                    .format(step_size_, l_, training_steps))
            
        self.wpm.set_value(np.concatenate((self.w_init, np.stack((self.p_init, self.m_init)))))

        # result = ([None]*11)
        for i in range(self.training_steps):
            result = WeightedPNormNR.train(data.train_X_samples, data.train_RT_samples, self.step_size_, self.l_)
            wpm, XPw, RT, epsilon, regularization_2, MSE, E, gradE, U, V, D, new_wpm = result
            if MSE < MSE_limit:
                break

        self.training_results = dict(zip(self.training_result_variables, result))
        self.training_results['i'] = i
        if verbose:
            print "MSE = {}".format(self.training_results['MSE'])

    def __call__(self, data):
        prediction_result = self.predict(data.test_X_samples, data.test_RT_samples)
        return dict(zip(self.prediction_result_variables, prediction_result))
        
        
    @classmethod
    def evaluate_init(cls, step_size, training_steps, data, N):
        """ Determine how the starting point of the iteration impacts the end-result.
        """
        results = defaultdict(list)
        for i in range(N):
            w_init = np.random.uniform(0, 1, cls.num_children)
            p_init = np.random.uniform(0.4, 4)
            m_init = np.random.uniform(-5, 5)
            wpn = WeightedPNormGradDesc(w_init, p_init, m_init, step_size, training_steps, data)
            results['w'].append(w)
            results['p'].append(p)
            results['mu'].append(m)  # (m, data.real_mu + data.real_sigma^2 /2)

            #RT_predictions, epsilon = predict(data.validation_X_samples, data.validation_RT_samples)
        pass  # plot RT_samples vs. RT_predictions
        pass  # plot the distribution of epsilon    
        return results
    
    @classmethod
    def evaluate_real(cls, step_size, l, training_steps, N, MSE_limit):
        """ Determine how the real values of the model parameters impact the error.
        """
        w_init = np.ones(cls.num_children) / cls.num_children
        p_init = 1.0
        m_init = 0.0
        results = list() #results = defaultdict(list)
        for i in range(N):
            if verbose:
                print "i = {}".format(i)
            locX = np.random.uniform(-1, 1, cls.num_children)
            scaleX = np.random.uniform(0, 2, cls.num_children)
            real_w = np.random.uniform(0, 1, cls.num_children)
            real_p = np.random.uniform(0.4, 4)
            real_mu = np.random.uniform(-1, 1)
            real_sigma = 0.0
            data = WeightedPNormSample(locX, scaleX, real_w, real_p, real_mu, real_sigma, 
                                       training_set_size=5000, 
                                       validation_set_size=0, 
                                       test_set_size=5000)
            wpn = WeightedPNormNR(w_init, p_init, m_init, step_size, l, training_steps, data, MSE_limit)
            results.append( (data, wpn.training_results, wpn(data)))
        return results

# %% [markdown]
# ## Examine the inversion of the Hessian

# %%
def evaluate_heassian(l_, N):
    """ 
    """
    w_init = np.ones(WeightedPNormNR.num_children) / WeightedPNormNR.num_children
    p_init = 1.0
    m_init = 0.0
    results = list() #results = defaultdict(list)
    for i in range(N):
        if verbose:
            print "i = {}".format(i)
        locX = np.random.uniform(-1, 1, WeightedPNormNR.num_children)
        scaleX = np.random.uniform(0, 2, WeightedPNormNR.num_children)
        real_w = w_init
        real_p = p_init
        real_mu = m_init
        real_sigma = 0.0
        data = WeightedPNormSample(locX, scaleX, real_w, real_p, real_mu, real_sigma, 
                                   training_set_size=5000, 
                                   validation_set_size=0, 
                                   test_set_size=0)
        wpn = WeightedPNormNR(w_init, p_init, m_init, step_size_=0, l_=l_, training_steps=1, data=data, MSE_limit=0.05)
        results.append( (data, wpn.training_results, wpn(data)))
    return results

# %%
def plot_singular_values(results,):
    series = defaultdict(list)
    for data, wpn_results, prediction_results in results:
#         series['U'].append(wpn_results['U'])
#         series['V'].append(wpn_results['V'])
        series['D'].append(wpn_results['D'])
        
    colors = cm.rainbow(np.linspace(0, 1, len(results)))
    for parameter, data in series.items():
        plt.title('Singular values of the Hessian')
        plt.grid()
        plt.yscale('log')
        for c, d in zip(colors, data):
            x = np.random.uniform(-0.4, 0.4, len(d)) 
            x += np.array(range(len(d))) + 1
            plt.scatter(x, d, alpha=0.02)
        plt.xlabel('Order of singular value')
        plt.ylabel('Singular value')
        plt.show()

# %%
verbose = False
results = evaluate_heassian(l_=l_, N=2000)
plot_singular_values(results)

# %% [markdown]
# The Hessian seems to be relatively well-conditioned. The typical range for the singular values is between $10^{-4}$ and $10^{4}$, the condition number (ratio of largest and smallest singular value) is typically less than $10^{-6}$.

# %%
np.ones(3)
# Out:
# array([ 1.,  1.,  1.])

# %% [markdown]
# ## Evaluate the fitting algorithm
# ### Generate data points for the evaluation
# For each data point:
#
# - a random value for the parameters locX, scaleX, real_w, real_p, real_mu, real_sigma is chosen
# - a training and a test data sets are generated
# - the model is fit to the training data
# - a prediction is generated on the test data using the fit model

# %%
verbose = True
results = WeightedPNormNR.evaluate_real(step_size=1.0, l=1e4, training_steps = 2000, N=50, MSE_limit=0.05)
# Out:
# i = 0
# Generating 5000 training, 0 validation and 5000 test samples using the following parameters:
# locX = [ 0.98034706 -0.30094709  0.36810508]        scaleX = [ 1.35647169  0.28535745  1.80442969]
# w = [ 0.90228898  0.96964411  0.57978527],        p = 2.1067311019,        mu = -0.619021988837,        sigma = 0.0
# Training the model using the following parameters:
# step_size = 1.0,	lambda = 10000.0,	training_steps = 2000
# MSE = 0.245341125656
# i = 1
# Generating 5000 training, 0 validation and 5000 test samples using the following parameters:
# locX = [ 0.71125485 -0.49495035  0.34246119]        scaleX = [ 1.0952556   1.91511907  1.4876764 ]
# w = [ 0.86232505  0.88630012  0.4008823 ],        p = 2.17636816081,        mu = 0.427807084405,        sigma = 0.0
# Training the model using the following parameters:
# step_size = 1.0,	lambda = 10000.0,	training_steps = 2000
# MSE = 0.204650666205
# i = 2
# Generating 5000 training, 0 validation and 5000 test samples using the following parameters:
# locX = [ 0.41322448 -0.74235501  0.31420183]        scaleX = [ 1.78679222  0.76082504  0.72288844]
# w = [ 0.71394664  0.6321863   0.72838243],        p = 0.487957119796,        mu = -0.716584094001,        sigma = 0.0
# Training the model using the following parameters:
# step_size = 1.0,	lambda = 10000.0,	training_steps = 2000
# MSE = 0.0499984947617
# i = 3
# Generating 5000 training, 0 validation and 5000 test samples using the following parameters:
# locX = [-0.77438406  0.73674568  0.7196453 ]        scaleX = [ 1.93222311  0.88408391  0.08818464]
# w = [ 0.56290875  0.16643977  0.98148234],        p = 3.53068148626,        mu = -0.857944087288,        sigma = 0.0
# Training the model using the following parameters:
# step_size = 1.0,	lambda = 10000.0,	training_steps = 2000
# MSE = 0.267891119191
# i = 4
# Generating 5000 training, 0 validation and 5000 test samples using the following parameters:
# locX = [-0.54922728 -0.78677596  0.75707242]        scaleX = [ 0.86561218  1.2625616   0.95621242]
# w = [ 0.88115713  0.01464077  0.43264818],        p = 2.05118524562,        mu = 0.62288673105,        sigma = 0.0
# Training the model using the following parameters:
# step_size = 1.0,	lambda = 10000.0,	training_steps = 2000
# MSE = 0.205752103292
# i = 5
# Generating 5000 training, 0 validation and 5000 test samples using the following parameters:
# locX = [-0.50994302 -0.42558838 -0.39246102]        scaleX = [ 0.98284001  1.05900191  1.85755916]
# w = [ 0.45836795  0.12933552  0.76643661],        p = 3.06065695934,        mu = -0.739852783963,        sigma = 0.0
# Training the model using the following parameters:
# step_size = 1.0,	lambda = 10000.0,	training_steps = 2000
# MSE = 0.191863193439
# i = 6
# Generating 5000 training, 0 validation and 5000 test samples using the following parameters:
# locX = [-0.12822615 -0.75630834  0.74230282]        scaleX = [ 1.74561604  0.46491061  0.2944861 ]
# w = [ 0.29551229  0.26302649  0.57296954],        p = 3.60767878536,        mu = 0.51042910497,        sigma = 0.0
# Training the model using the following parameters:
# step_size = 1.0,	lambda = 10000.0,	training_steps = 2000
# MSE = 0.193213122817
# i = 7
# Generating 5000 training, 0 validation and 5000 test samples using the following parameters:
# locX = [-0.38106461 -0.74695585  0.94879698]        scaleX = [ 1.18000455  0.62875179  1.28762674]
# w = [ 0.45214039  0.74608328  0.85243645],        p = 1.59094234703,        mu = -0.219259458826,        sigma = 0.0
# Training the model using the following parameters:
# step_size = 1.0,	lambda = 10000.0,	training_steps = 2000
# MSE = 0.053087601543
# i = 8
# Generating 5000 training, 0 validation and 5000 test samples using the following parameters:
# locX = [-0.76794294  0.0763337   0.82970276]        scaleX = [ 1.53100109  1.20845908  0.43812544]
# w = [ 0.60605936  0.32736879  0.79418429],        p = 0.574001845127,        mu = 0.577683471758,        sigma = 0.0
# Training the model using the following parameters:
# step_size = 1.0,	lambda = 10000.0,	training_steps = 2000
# MSE = 0.0582929438746
# i = 9
# Generating 5000 training, 0 validation and 5000 test samples using the following parameters:
# locX = [-0.66323793 -0.89467217  0.54950725]        scaleX = [ 0.63746349  1.31549497  1.98575895]
# w = [ 0.05825908  0.05955294  0.06388098],        p = 3.15053477226,        mu = 0.710814550048,        sigma = 0.0
# Training the model using the following parameters:
# step_size = 1.0,	lambda = 10000.0,	training_steps = 2000
# MSE = 0.203889243332
# i = 10
# Generating 5000 training, 0 validation and 5000 test samples using the following parameters:
# locX = [ 0.83675817  0.39702964  0.76707994]        scaleX = [ 0.20571618  0.57361036  0.11336049]
# w = [ 0.60942233  0.38929957  0.86050401],        p = 1.31656098678,        mu = -0.991610581637,        sigma = 0.0
# Training the model using the following parameters:
# step_size = 1.0,	lambda = 10000.0,	training_steps = 2000
# MSE = 0.0499737302332
# i = 11
# Generating 5000 training, 0 validation and 5000 test samples using the following parameters:
# locX = [-0.97184454 -0.13477731  0.18294181]        scaleX = [ 1.63693073  0.71753568  1.10987399]
# w = [ 0.25786159  0.83691642  0.52805593],        p = 2.10804840657,        mu = -0.624149162077,        sigma = 0.0
# Training the model using the following parameters:
# step_size = 1.0,	lambda = 10000.0,	training_steps = 2000
# MSE = 0.166552220647
# i = 12
# Generating 5000 training, 0 validation and 5000 test samples using the following parameters:
# locX = [-0.53261152  0.90887417 -0.00176524]        scaleX = [ 0.48555894  1.1438396   1.63432096]
# w = [ 0.14222295  0.74837244  0.56112532],        p = 0.731267687256,        mu = 0.452630862546,        sigma = 0.0
# Training the model using the following parameters:
# step_size = 1.0,	lambda = 10000.0,	training_steps = 2000
# MSE = 0.0499786678889
# i = 13
# Generating 5000 training, 0 validation and 5000 test samples using the following parameters:
# locX = [-0.71329532  0.92138821  0.31536867]        scaleX = [ 1.35149662  1.9786662   0.91462498]
# w = [ 0.87119712  0.31498074  0.78049286],        p = 0.677511266702,        mu = -0.428881928066,        sigma = 0.0
# Training the model using the following parameters:
# step_size = 1.0,	lambda = 10000.0,	training_steps = 2000
# MSE = 0.0499750868341
# i = 14
# Generating 5000 training, 0 validation and 5000 test samples using the following parameters:
# locX = [ 0.86834464 -0.51921396 -0.95448222]        scaleX = [ 1.53205706  0.61830478  1.95170009]
# w = [ 0.21167859  0.99408208  0.92957069],        p = 2.65819335828,        mu = -0.983422543964,        sigma = 0.0
# Training the model using the following parameters:
# step_size = 1.0,	lambda = 10000.0,	training_steps = 2000
# MSE = 0.375577372969
# i = 15
# Generating 5000 training, 0 validation and 5000 test samples using the following parameters:
# locX = [-0.23709101  0.69764101  0.10862208]        scaleX = [ 1.05339418  1.18669763  1.81964121]
# w = [ 0.63243501  0.53065936  0.54494465],        p = 3.69547531321,        mu = -0.414427534797,        sigma = 0.0
# Training the model using the following parameters:
# step_size = 1.0,	lambda = 10000.0,	training_steps = 2000
# MSE = 0.450509606801
# i = 16
# Generating 5000 training, 0 validation and 5000 test samples using the following parameters:
# locX = [ 0.64549595 -0.76071881 -0.1265684 ]        scaleX = [ 1.56806851  0.577999    1.37691939]
# w = [ 0.15039006  0.49716594  0.27064298],        p = 2.25783060795,        mu = 0.0613294779469,        sigma = 0.0
# Training the model using the following parameters:
# step_size = 1.0,	lambda = 10000.0,	training_steps = 2000
# MSE = 0.131663015239
# i = 17
# Generating 5000 training, 0 validation and 5000 test samples using the following parameters:
# locX = [-0.93401066  0.60498954  0.05923553]        scaleX = [ 0.1000289   0.54172557  1.5447381 ]
# w = [ 0.46245012  0.56231431  0.9218383 ],        p = 1.94535667674,        mu = -0.315437815923,        sigma = 0.0
# Training the model using the following parameters:
# step_size = 1.0,	lambda = 10000.0,	training_steps = 2000
# MSE = 0.0920976139255
# i = 18
# Generating 5000 training, 0 validation and 5000 test samples using the following parameters:
# locX = [ 0.02070302 -0.99638421  0.14209062]        scaleX = [ 1.50679596  0.00615068  0.05865545]
# w = [ 0.82425597  0.13426038  0.14914439],        p = 1.23667065235,        mu = -0.147635276062,        sigma = 0.0
# Training the model using the following parameters:
# step_size = 1.0,	lambda = 10000.0,	training_steps = 2000
# MSE = 0.0499894691129
# i = 19
# Generating 5000 training, 0 validation and 5000 test samples using the following parameters:
# locX = [ 0.71774553 -0.58932973  0.68825223]        scaleX = [ 1.58783541  0.01426554  1.57119523]
# w = [ 0.54591992  0.84856812  0.48585893],        p = 1.25056946709,        mu = -0.914694532821,        sigma = 0.0
# Training the model using the following parameters:
# step_size = 1.0,	lambda = 10000.0,	training_steps = 2000
# MSE = 0.0604782284037
# i = 20
# Generating 5000 training, 0 validation and 5000 test samples using the following parameters:
# locX = [-0.34266706  0.62434627  0.37093135]        scaleX = [ 0.36210824  1.72713121  1.16647639]
# w = [ 0.24306909  0.93500142  0.20760703],        p = 2.41641916671,        mu = -0.932017830435,        sigma = 0.0
# Training the model using the following parameters:
# step_size = 1.0,	lambda = 10000.0,	training_steps = 2000
# MSE = 0.316895026852
# i = 21
# Generating 5000 training, 0 validation and 5000 test samples using the following parameters:
# locX = [-0.56960675  0.27011193 -0.8102511 ]        scaleX = [ 1.6864737   1.80973612  1.29594463]
# w = [ 0.14012602  0.14395207  0.41765944],        p = 0.972663454561,        mu = -0.587356614704,        sigma = 0.0
# Training the model using the following parameters:
# step_size = 1.0,	lambda = 10000.0,	training_steps = 2000
# MSE = 0.0581626842627
# i = 22
# Generating 5000 training, 0 validation and 5000 test samples using the following parameters:
# locX = [ 0.3968169  -0.11633593  0.64430102]        scaleX = [ 1.61455549  1.6230328   0.26118743]
# w = [ 0.84951622  0.50914531  0.2685761 ],        p = 1.88692371591,        mu = -0.264275805035,        sigma = 0.0
# Training the model using the following parameters:
# step_size = 1.0,	lambda = 10000.0,	training_steps = 2000
# MSE = 0.127011247042
# i = 23
# Generating 5000 training, 0 validation and 5000 test samples using the following parameters:
# locX = [ 0.29555891  0.19290531 -0.39576841]        scaleX = [ 0.91594068  1.73248306  0.18489014]
# w = [ 0.29668686  0.5756326   0.32939608],        p = 0.525286327782,        mu = -0.731489514377,        sigma = 0.0
# Training the model using the following parameters:
# step_size = 1.0,	lambda = 10000.0,	training_steps = 2000
# MSE = 0.184262212438
# i = 24
# Generating 5000 training, 0 validation and 5000 test samples using the following parameters:
# locX = [ 0.88254569  0.49843094  0.82391486]        scaleX = [ 1.62393245  0.87235684  0.19261806]
# w = [ 0.93040454  0.85478065  0.17055622],        p = 3.70518544851,        mu = 0.192976607999,        sigma = 0.0
# Training the model using the following parameters:
# step_size = 1.0,	lambda = 10000.0,	training_steps = 2000
# MSE = 0.349603651301
# i = 25
# Generating 5000 training, 0 validation and 5000 test samples using the following parameters:
# locX = [-0.21993984 -0.1728563   0.92794668]        scaleX = [ 0.70336376  1.74975481  0.89128293]
# w = [ 0.03519127  0.52189901  0.36654656],        p = 3.93840021826,        mu = -0.496303291887,        sigma = 0.0
# Training the model using the following parameters:
# step_size = 1.0,	lambda = 10000.0,	training_steps = 2000
# MSE = 0.389850075951
# i = 26
# Generating 5000 training, 0 validation and 5000 test samples using the following parameters:
# locX = [-0.80243878  0.13309162 -0.52129991]        scaleX = [ 0.16950317  1.40866599  0.65415552]
# w = [ 0.30560918  0.5924466   0.92299214],        p = 2.73496890395,        mu = -0.087003453142,        sigma = 0.0
# Training the model using the following parameters:
# step_size = 1.0,	lambda = 10000.0,	training_steps = 2000
# MSE = 0.0499540092024
# i = 27
# Generating 5000 training, 0 validation and 5000 test samples using the following parameters:
# locX = [-0.58559833 -0.51953304  0.38918252]        scaleX = [ 1.43028631  0.47214782  0.87844433]
# w = [ 0.56354524  0.92844242  0.81808681],        p = 0.659329535959,        mu = 0.0622067497657,        sigma = 0.0
# Training the model using the following parameters:
# step_size = 1.0,	lambda = 10000.0,	training_steps = 2000
# MSE = 0.191329414242
# i = 28
# Generating 5000 training, 0 validation and 5000 test samples using the following parameters:
# locX = [-0.74629165  0.28274252 -0.77843893]        scaleX = [ 1.97198901  1.43442595  0.36592319]
# w = [ 0.24306586  0.61851402  0.25693352],        p = 3.57849652994,        mu = 0.368434525633,        sigma = 0.0
# Training the model using the following parameters:
# step_size = 1.0,	lambda = 10000.0,	training_steps = 2000
# MSE = 0.185905810039
# i = 29
# Generating 5000 training, 0 validation and 5000 test samples using the following parameters:
# locX = [ 0.89911359 -0.51603448  0.65095145]        scaleX = [ 1.86806973  1.9399962   1.81699427]
# w = [ 0.12823577  0.38799498  0.9780904 ],        p = 0.911509422859,        mu = -0.555535866197,        sigma = 0.0
# Training the model using the following parameters:
# step_size = 1.0,	lambda = 10000.0,	training_steps = 2000
# MSE = 0.0499934599713
# i = 30
# Generating 5000 training, 0 validation and 5000 test samples using the following parameters:
# locX = [ 0.35998608 -0.77948875  0.00446903]        scaleX = [ 0.21382954  0.97590798  0.18861062]
# w = [ 0.21008812  0.68647277  0.66749899],        p = 3.84564292727,        mu = 0.30973931538,        sigma = 0.0
# Training the model using the following parameters:
# step_size = 1.0,	lambda = 10000.0,	training_steps = 2000
# MSE = 0.0572330489641
# i = 31
# Generating 5000 training, 0 validation and 5000 test samples using the following parameters:
# locX = [ 0.73901924  0.58287799  0.43288436]        scaleX = [ 1.41873856  0.03438979  1.37998918]
# w = [ 0.93902921  0.13762036  0.71093492],        p = 2.48863213837,        mu = -0.160269468352,        sigma = 0.0
# Training the model using the following parameters:
# step_size = 1.0,	lambda = 10000.0,	training_steps = 2000
# MSE = 0.271110749857
# i = 32
# Generating 5000 training, 0 validation and 5000 test samples using the following parameters:
# locX = [ 0.70355675  0.99019787 -0.00815097]        scaleX = [ 1.86769591  0.41155551  1.86354932]
# w = [ 0.06797178  0.85217502  0.67041282],        p = 1.68365608414,        mu = -0.109670472479,        sigma = 0.0
# Training the model using the following parameters:
# step_size = 1.0,	lambda = 10000.0,	training_steps = 2000
# MSE = 0.190186642629
# i = 33
# Generating 5000 training, 0 validation and 5000 test samples using the following parameters:
# locX = [ 0.47245985  0.17339199  0.59889583]        scaleX = [ 0.43793579  1.90515103  0.50695032]
# w = [ 0.08545831  0.50465646  0.60832576],        p = 2.78009557161,        mu = 0.906880041089,        sigma = 0.0
# Training the model using the following parameters:
# step_size = 1.0,	lambda = 10000.0,	training_steps = 2000
# MSE = 0.261008586076
# i = 34
# Generating 5000 training, 0 validation and 5000 test samples using the following parameters:
# locX = [ 0.4262512  -0.41518304 -0.2959151 ]        scaleX = [ 1.35480381  1.02326478  0.54001437]
# w = [ 0.60078503  0.32238348  0.29767298],        p = 1.95223728506,        mu = -0.307266110205,        sigma = 0.0
# Training the model using the following parameters:
# step_size = 1.0,	lambda = 10000.0,	training_steps = 2000
# MSE = 0.0741525689031
# i = 35
# Generating 5000 training, 0 validation and 5000 test samples using the following parameters:
# locX = [ 0.86563199 -0.27210732 -0.29569767]        scaleX = [ 0.32912552  1.10015447  0.08044132]
# w = [ 0.96395727  0.76652243  0.88166492],        p = 3.4815153095,        mu = 0.154897749287,        sigma = 0.0
# Training the model using the following parameters:
# step_size = 1.0,	lambda = 10000.0,	training_steps = 2000
# MSE = 0.128315520411
# i = 36
# Generating 5000 training, 0 validation and 5000 test samples using the following parameters:
# locX = [-0.4614079   0.83114716 -0.65217623]        scaleX = [ 0.746377    1.95316883  1.132804  ]
# w = [ 0.67685242  0.30776138  0.07729062],        p = 3.3517522987,        mu = -0.874916778899,        sigma = 0.0
# Training the model using the following parameters:
# step_size = 1.0,	lambda = 10000.0,	training_steps = 2000
# MSE = 0.204073304512
# i = 37
# Generating 5000 training, 0 validation and 5000 test samples using the following parameters:
# locX = [-0.81574784 -0.61449765 -0.76382343]        scaleX = [ 0.13360626  1.82872738  1.39580101]
# w = [ 0.22265154  0.71976644  0.99425106],        p = 0.948447271865,        mu = -0.125629978894,        sigma = 0.0
# Training the model using the following parameters:
# step_size = 1.0,	lambda = 10000.0,	training_steps = 2000
# MSE = 0.049942829357
# i = 38
# Generating 5000 training, 0 validation and 5000 test samples using the following parameters:
# locX = [-0.30083077  0.25902485  0.73633648]        scaleX = [ 1.27160188  0.15467424  1.1676309 ]
# w = [ 0.40369754  0.93007138  0.76715762],        p = 2.1768962096,        mu = 0.0724037524507,        sigma = 0.0
# Training the model using the following parameters:
# step_size = 1.0,	lambda = 10000.0,	training_steps = 2000
# MSE = 0.109205014256
# i = 39
# Generating 5000 training, 0 validation and 5000 test samples using the following parameters:
# locX = [-0.35305717 -0.35819521 -0.34181007]        scaleX = [ 0.54688534  1.93618932  0.24435135]
# w = [ 0.7906496   0.1521881   0.79707349],        p = 0.492110110178,        mu = -0.524646478536,        sigma = 0.0
# Training the model using the following parameters:
# step_size = 1.0,	lambda = 10000.0,	training_steps = 2000
# MSE = 0.435892780964
# i = 40
# Generating 5000 training, 0 validation and 5000 test samples using the following parameters:
# locX = [-0.89874895 -0.88460232  0.79863387]        scaleX = [ 0.34209765  1.92940664  1.01153148]
# w = [ 0.58814646  0.24641539  0.01560747],        p = 2.23491459741,        mu = 0.732511698456,        sigma = 0.0
# Training the model using the following parameters:
# step_size = 1.0,	lambda = 10000.0,	training_steps = 2000
# MSE = 0.231912012488
# i = 41
# Generating 5000 training, 0 validation and 5000 test samples using the following parameters:
# locX = [ 0.22804809  0.45071382 -0.49149162]        scaleX = [ 1.26403741  1.05560876  1.47908116]
# w = [ 0.85514941  0.07379452  0.93840588],        p = 0.801306147407,        mu = 0.814080695674,        sigma = 0.0
# Training the model using the following parameters:
# step_size = 1.0,	lambda = 10000.0,	training_steps = 2000
# MSE = 0.249769421376
# i = 42
# Generating 5000 training, 0 validation and 5000 test samples using the following parameters:
# locX = [-0.16233651 -0.04691963  0.3109609 ]        scaleX = [ 1.92184055  0.77122189  1.35530409]
# w = [ 0.58071411  0.6688495   0.67750921],        p = 2.91987669429,        mu = -0.780214420049,        sigma = 0.0
# Training the model using the following parameters:
# step_size = 1.0,	lambda = 10000.0,	training_steps = 2000
# MSE = 0.37762834301
# i = 43
# Generating 5000 training, 0 validation and 5000 test samples using the following parameters:
# locX = [ 0.48551988  0.36703    -0.26168509]        scaleX = [ 0.70628773  1.43516774  0.41499435]
# w = [ 0.25192533  0.33537502  0.68059704],        p = 2.90631811858,        mu = -0.620451093872,        sigma = 0.0
# Training the model using the following parameters:
# step_size = 1.0,	lambda = 10000.0,	training_steps = 2000
# MSE = 0.166948759902
# i = 44
# Generating 5000 training, 0 validation and 5000 test samples using the following parameters:
# locX = [-0.29546273  0.16883928  0.31514134]        scaleX = [ 0.84962391  1.91060557  0.02383775]
# w = [ 0.29918089  0.34367086  0.21335347],        p = 3.98923013328,        mu = 0.631708234194,        sigma = 0.0
# Training the model using the following parameters:
# step_size = 1.0,	lambda = 10000.0,	training_steps = 2000
# MSE = 0.138796804312
# i = 45
# Generating 5000 training, 0 validation and 5000 test samples using the following parameters:
# locX = [ 0.10847974  0.84946062  0.85708764]        scaleX = [ 1.90934854  0.04750869  1.81231928]
# w = [ 0.52501536  0.60543403  0.03190081],        p = 1.54373595098,        mu = -0.83494741112,        sigma = 0.0
# Training the model using the following parameters:
# step_size = 1.0,	lambda = 10000.0,	training_steps = 2000
# MSE = 0.0986284368669
# i = 46
# Generating 5000 training, 0 validation and 5000 test samples using the following parameters:
# locX = [-0.1756111   0.02445243 -0.4729528 ]        scaleX = [ 0.38713483  1.82035806  0.40110756]
# w = [ 0.35231297  0.22668091  0.92614629],        p = 1.38730254281,        mu = 0.628764159094,        sigma = 0.0
# Training the model using the following parameters:
# step_size = 1.0,	lambda = 10000.0,	training_steps = 2000
# MSE = 0.206576328447
# i = 47
# Generating 5000 training, 0 validation and 5000 test samples using the following parameters:
# locX = [ 0.27726177 -0.61361953 -0.03812681]        scaleX = [ 1.79720514  0.46741334  0.71971999]
# w = [ 0.18765664  0.97561116  0.97595224],        p = 0.979985672508,        mu = 0.747821955323,        sigma = 0.0
# Training the model using the following parameters:
# step_size = 1.0,	lambda = 10000.0,	training_steps = 2000
# MSE = 0.265652639715
# i = 48
# Generating 5000 training, 0 validation and 5000 test samples using the following parameters:
# locX = [ 0.03026945  0.86904122 -0.6550355 ]        scaleX = [ 1.92197357  0.32243145  0.27987347]
# w = [ 0.36256406  0.44681966  0.94437758],        p = 3.8040330037,        mu = 0.569903382997,        sigma = 0.0
# Training the model using the following parameters:
# step_size = 1.0,	lambda = 10000.0,	training_steps = 2000
# MSE = 0.203294437732
# i = 49
# Generating 5000 training, 0 validation and 5000 test samples using the following parameters:
# locX = [ 0.84005505 -0.91727059  0.05701654]        scaleX = [ 1.27494707  0.7667884   0.13914943]
# w = [ 0.8050754   0.20087815  0.99002487],        p = 3.06624000256,        mu = 0.859729970112,        sigma = 0.0
# Training the model using the following parameters:
# step_size = 1.0,	lambda = 10000.0,	training_steps = 2000
# MSE = 0.240531126584

# %% [markdown]
# ### Examine the mean squared error on the training and test data sets

# %%
def plot_MSE_vs_MSE(results):
    series = defaultdict(list)
    for data, wpn_results, prediction_results in results:
        series['MSE'].append((wpn_results['MSE'], prediction_results['MSE'], ))
    
    for parameter, data in series.items():
        plt.title('MSE computed on the training vs. test data sets ')
        plt.grid()
        plt.scatter(*zip(*data))
        plt.xlabel('Training MSE')
        plt.ylabel('Test MSE')
        plt.show()
plot_MSE_vs_MSE(results)

# %% [markdown]
# ### Examine the dependence of the MSE on the actual model parameters
# Is there a particular domain of some of the parameters that cause the high MSE?

# %%
def plot_MSE_vs_prediction(results):
    series = defaultdict(list)
    for data, wpn_results, prediction_results in results:
        series['w_0'].append((data.real_w[0], prediction_results['MSE'], ))
        series['w_1'].append((data.real_w[1], prediction_results['MSE'], ))
        series['w_2'].append((data.real_w[2], prediction_results['MSE'], ))
        series['p'  ].append((data.real_p   , prediction_results['MSE'], ))
        series['m'  ].append((data.real_mu + data.real_sigma**2.0/2, prediction_results['MSE'], ))
    
    for parameter, data in series.items():
        plt.title('Dependence of the MSE on the actual value of {}'.format(parameter))
        plt.grid()
        plt.scatter(*zip(*data))
        plt.xlabel(parameter)
        plt.ylabel('MSE')
        plt.show()

# %%
plot_MSE_vs_prediction(results)

# %% [markdown]
# # Summary
# Near the global minimum the Hessian is invertible and its condition number is moderate.
#
# When the global minimum is far, strong relularization was necessary to make the SVD computation converge. It is probably due to this strong regularization that the resulting convergence of the Newton-Raphson algorithm is slow and often the solution is far from the global minima even after 2000 iterations.
